# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5
}

# %%
messages = []
add_user_message(
    messages,
    """
    What is the current price of Bitcoin?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01Pm85LZAJRziLF9sNES4sxk', container=None, content=[ServerToolUseBlock(id='srvtoolu_018GvFeAFQfPsMaCg1AMziH4', caller=None, input={'query': 'Bitcoin price today'}, name='web_search', type='server_tool_use'), WebSearchToolResultBlock(caller=DirectCaller(type='direct'), content=[WebSearchResultBlock(encrypted_content='...', page_age='4 hours ago', title='Bitcoin Price: BTC/USD Live Price Chart, Market Cap & News Today | CoinGecko', type='web_search_result', url='https://www.coingecko.com/en/coins/bitcoin'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Bitcoin Price Today: BTC Retraces After May US PPI Hits 4-Year High of 6.5% | | CryptoRank.io', type='web_search_result', url='https://cryptorank.io/news/feed/c15d5-bitcoin-price-today-btc-retraces-after-may-us-ppi-hits-4-year-high-of-6-5'), WebSearchResultBlock(encrypted_content='...', page_age='1 week ago', title='Bitcoin price today, BTC to USD live price, marketcap and chart | CoinDesk', type='web_search_result', url='https://www.coindesk.com/price/bitcoin'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Crypto Prices Today: Bitcoin Holds Near $63,579 as PPI Hits 6.5%, SpaceX IPO Drains Market Liquidity', type='web_search_result', url='https://www.analyticsinsight.net/price-analysis/crypto-prices-today-bitcoin-holds-near-63579-as-ppi-hits-65-spacex-ipo-drains-market-liquidity'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Bitcoin and ethereum prices today, Friday, June 12, 2026: Prices rebound this morning after Trump claims war has ended', type='web_search_result', url='https://finance.yahoo.com/personal-finance/investing/article/bitcoin-and-ethereum-prices-today-friday-june-12-2026-prices-rebound-this-morning-after-trump-claims-war-has-ended-115949042.html'), WebSearchResultBlock(encrypted_content='...', page_age='11 hours ago', title='Bitcoin (BTC) Price USD Today, News, Charts, Market Cap | Coinbase', type='web_search_result', url='https://www.coinbase.com/price/bitcoin'), WebSearchResultBlock(encrypted_content='...', page_age='6 days ago', title='Buy Bitcoin - BTC Price Today, Live Charts and News', type='web_search_result', url='https://robinhood.com/us/en/crypto/BTC/'), WebSearchResultBlock(encrypted_content='...', page_age=None, title='Bitcoin price today - BTC price chart & live trends', type='web_search_result', url='https://www.kraken.com/prices/bitcoin'), WebSearchResultBlock(encrypted_content='...', page_age='19 hours ago', title='Bitcoin Price Today | BTC Live Price, Chart & Market Cap | OKX United States', type='web_search_result', url='https://www.okx.com/en-us/price/bitcoin-btc'), WebSearchResultBlock(encrypted_content='...', page_age='1 week ago', title='Bitcoin Price Today | BTC to USD Live Price, Market Cap & ...', type='web_search_result', url='https://www.binance.com/en/price/bitcoin')], tool_use_id='srvtoolu_018GvFeAFQfPsMaCg1AMziH4', type='web_search_tool_result'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='The price of Bitcoin (BTC) is $64,250.39 today with a 24-hour trading volume of $17,234,107,996.76. ', encrypted_index='Eo8BCioIEBgCIiQ5ODk4NGEzNi03NzBjLTQyNmYtOGY4ZS01MjM4ZDlhZDBlODcSDDJrrQEoqDgN8L3AExoM/brrlXSN8BPYkzLEIjAWuRz2zA5uRefGuieeaBZkSU3+sNi4G/fdCJnAGaOFbKqjrhrtMjbSvrvyFgMNK90qEwZK6TChbFS7xidVXFiPxxw/gO8YBA==', title='Bitcoin Price: BTC/USD Live Price Chart, Market Cap & News Today | CoinGecko', type='web_search_result_location', url='https://www.coingecko.com/en/coins/bitcoin')], text='The current price of Bitcoin (BTC) is $64,250.39', type='text'), TextBlock(citations=None, text=', with ', type='text'), TextBlock(citations=[CitationsWebSearchResultLocation(cited_text='This represents a 1.30% price increase in the last 24 hours and a 5.80% price increase in the past 7 days. ', encrypted_index='Eo8BCioIEBgCIiQ5ODk4NGEzNi03NzBjLTQyNmYtOGY4ZS01MjM4ZDlhZDBlODcSDJ9UUoqkYTCNMcGKBhoMCzDvA/6ENoS+PiERIjDUea+ZYFwp9KDoOysDk6u641lTY0VqDyVFGV88lmU ...
